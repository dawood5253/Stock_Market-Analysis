# %% [markdown]
# <a href="https://colab.research.google.com/github/dawood5253/Stock_Market-Analysis/blob/main/Xenalytics_Joel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Price Analysis : Xenalytics

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Datasets

# %%
lumina = pd.read_csv("/content/drive/MyDrive/Xenalytics /Lumina.csv", parse_dates=['Date'],index_col=["Date"])
nexus = pd.read_csv("/content/drive/MyDrive/Xenalytics /Nexus.csv",parse_dates=['Date'],index_col=["Date"])
quantumize = pd.read_csv("/content/drive/MyDrive/Xenalytics /Quantumize.csv",parse_dates=['Date'],index_col=["Date"])
synthify = pd.read_csv("/content/drive/MyDrive/Xenalytics /Synthify.csv",parse_dates=['Date'],index_col=["Date"])
zenith = pd.read_csv("/content/drive/MyDrive/Xenalytics /Zenith.csv",parse_dates=['Date'],index_col=["Date"])

# %%
df = pd.concat([lumina['Stock_Price'], nexus['Stock_Price'], quantumize['Stock_Price'],
                synthify['Stock_Price'], zenith['Stock_Price']], axis=1)

df.columns = ['Lumina', 'Nexus', 'Quantumize', 'Synthify', 'Zenith']

correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, vmin=-1, vmax=1)
plt.title('Stock Price Correlation Matrix')
plt.show()

# %%
lumina = pd.read_csv("Lumina.csv", parse_dates=['Date'],index_col=["Date"])
nexus = pd.read_csv("Nexus.csv",parse_dates=['Date'],index_col=["Date"])
quantumize = pd.read_csv("Quantumize.csv",parse_dates=['Date'],index_col=["Date"])
synthify = pd.read_csv("Synthify.csv",parse_dates=['Date'],index_col=["Date"])
zenith = pd.read_csv("Zenith.csv",parse_dates=['Date'],index_col=["Date"])
# Out:
# <ipython-input-39-211468691edc>:1: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.

# %%
zenith.index[0]
# Out:
# Timestamp('2024-01-01 00:00:00')

# %%
lumina.dtypes
# Out:
# Stock_Price    int64
# dtype: object

# %%
plt.style.use('fivethirtyeight')
lumina.plot(figsize=(8,4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
nexus.plot(figsize=(8 ,4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
quantumize.plot(figsize=(8, 4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
zenith.plot(figsize=(8, 4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
synthify.plot(figsize=(8, 4))
plt.ylabel("Price")
plt.title("stock price", fontsize=16)
plt.legend(fontsize=14);

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming zenith['Date'] is in datetime format
zenith['Volatility'] = zenith['Stock_Price'].pct_change().rolling(window=len(zenith), min_periods=1).std()

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

# Plot stock price on the top subplot
ax1.plot(zenith.index, zenith['Stock_Price'], label='Stock Price', color='blue')
ax1.set_ylabel('Price')
ax1.set_title('Stock Price', fontsize=16)
ax1.legend(fontsize=12)

# Plot volatility on the bottom subplot
ax2.plot(zenith.index, zenith['Volatility'], label='Volatility', color='orange')
ax2.set_title('Volatility Over Time')
ax2.set_xlabel('Date')
ax2.set_ylabel('Volatility')

# Rotate the date labels for better readability
ax2.tick_params(axis='x', rotation=45)

ax2.legend(fontsize=12)

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Synthify
synthify['Volatility'] = synthify['Stock_Price'].pct_change().rolling(window=len(synthify), min_periods=1).std()

# Create subplots for Synthify
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

# Plot stock price on the top subplot for Synthify
ax1.plot(synthify.index, synthify['Stock_Price'], label='Stock Price', color='blue')
ax1.set_ylabel('Price')
ax1.set_title('Synthify Stock Price', fontsize=16)
ax1.legend(fontsize=12)

# Plot volatility on the bottom subplot for Synthify
ax2.plot(synthify.index, synthify['Volatility'], label='Volatility', color='orange')
ax2.set_title('Volatility Over Time for Synthify')
ax2.set_xlabel('Date')
ax2.set_ylabel('Volatility')

# Rotate the date labels for better readability
ax2.tick_params(axis='x', rotation=45)

ax2.legend(fontsize=12)

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
nexus['Volatility'] = nexus['Stock_Price'].pct_change().rolling(window=len(nexus), min_periods=1).std()

# Create subplots for Nexus
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

# Plot stock price on the top subplot for Nexus
ax1.plot(nexus.index, nexus['Stock_Price'], label='Stock Price', color='blue')
ax1.set_ylabel('Price')
ax1.set_title('Nexus Stock Price', fontsize=16)
ax1.legend(fontsize=12)

# Plot volatility on the bottom subplot for Nexus
ax2.plot(nexus.index, nexus['Volatility'], label='Volatility', color='orange')
ax2.set_title('Volatility Over Time for Nexus')
ax2.set_xlabel('Date')
ax2.set_ylabel('Volatility')

# Rotate the date labels for better readability
ax2.tick_params(axis='x', rotation=45)

ax2.legend(fontsize=12)

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
quantumize['Volatility'] = quantumize['Stock_Price'].pct_change().rolling(window=len(quantumize), min_periods=1).std()

# Create subplots for Quantumize
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

# Plot stock price on the top subplot for Quantumize
ax1.plot(quantumize.index, quantumize['Stock_Price'], label='Stock Price', color='blue')
ax1.set_ylabel('Price')
ax1.set_title('Quantumize Stock Price', fontsize=16)
ax1.legend(fontsize=12)

# Plot volatility on the bottom subplot for Quantumize
ax2.plot(quantumize.index, quantumize['Volatility'], label='Volatility', color='orange')
ax2.set_title('Volatility Over Time for Quantumize')
ax2.set_xlabel('Date')
ax2.set_ylabel('Volatility')

# Rotate the date labels for better readability
ax2.tick_params(axis='x', rotation=45)

ax2.legend(fontsize=12)

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming lumina['Date'] is in datetime format
lumina['Volatility'] = lumina['Stock_Price'].pct_change().rolling(window=len(lumina), min_periods=1).std()

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

# Plot stock price on the top subplot
ax1.plot(lumina.index, lumina['Stock_Price'], label='Stock Price', color='blue')
ax1.set_ylabel('Price')
ax1.set_title('Lumina Stock Price', fontsize=16)
ax1.legend(fontsize=12)

# Plot volatility on the bottom subplot
ax2.plot(lumina.index, lumina['Volatility'], label='Volatility', color='orange')
ax2.set_title('Volatility Over Time for Lumina')
ax2.set_xlabel('Date')
ax2.set_ylabel('Volatility')

# Rotate the date labels for better readability
ax2.tick_params(axis='x', rotation=45)

ax2.legend(fontsize=12)

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# ## Lumina Stock

# %%
# Get date array
timesteps = lumina.index.to_numpy()
prices = lumina["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([50, 53, 57, 52, 58, 55, 60, 56, 59, 62]))

# %% [markdown]
# ### Naive Base Model

# %%
split_size = int(0.8 * len(prices)) # 80% train, 20% test

# Create train data splits (everything before the split)
X_train, y_train = timesteps[:split_size], prices[:split_size]

# Create test data splits (everything after the split)
X_test, y_test = timesteps[split_size:], prices[split_size:]

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (36, 10, 36, 10)

# %%
def plot_time_series(timesteps, values, format='.', start=0, end=None, label=None):
  """
  Plots a timesteps (a series of points in time) against values (a series of values across timesteps).

  Parameters
  ---------
  timesteps : array of timesteps
  values : array of values across time
  format : style of plot, default "."
  start : where to start the plot (setting a value will index from start of timesteps & values)
  end : where to end the plot (setting a value will index from end of timesteps & values)
  label : label to show on plot of values
  """
  # Plot the series
  plt.plot(timesteps[start:end], values[start:end], format, label=label)
  plt.xlabel("Time")
  plt.ylabel("StockPrice")
  if label:
    plt.legend(fontsize=14) # make label bigger
  plt.grid(True)

# %%
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_train, values=y_train, label="Train data")
plot_time_series(timesteps=X_test, values=y_test, label="Test data")

# %%
# Create a naïve forecast
naive_forecast = y_test[:-1]
naive_forecast[:10], naive_forecast[-10:]
# Out:
# (array([78, 81, 85, 88, 85, 82, 79, 82, 85]),
#  array([78, 81, 85, 88, 85, 82, 79, 82, 85]))

# %%
# Plot naive forecast
plt.figure(figsize=(10, 7))
plot_time_series(timesteps=X_train, values=y_train, label="Train data")
plot_time_series(timesteps=X_test, values=y_test, label="Test data")
plot_time_series(timesteps=X_test[1:], values=naive_forecast, format="-", label="Naive forecast");

# %%
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1]))

  return mae / mae_naive_no_season

# %%
def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred) # puts and emphasis on outliers (all errors get squared)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
  mase = mean_absolute_scaled_error(y_true, y_pred)

  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": mape.numpy(),
          "mase": mase.numpy()}

# %%
naive_results = evaluate_preds(y_true=y_test[1:],
                               y_pred=naive_forecast)
naive_results
# Out:
# {'mae': 3.1111112,
#  'mse': 9.777778,
#  'rmse': 3.1269438,
#  'mape': 3.711237,
#  'mase': 0.9955556}

# %% [markdown]
# ### Windowing dataset

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
def get_labelled_windows(x, horizon=1):
  """
  Creates labels for windowed dataset.

  E.g. if horizon=1 (default)
  Input: [1, 2, 3, 4, 5, 6] -> Output: ([1, 2, 3, 4, 5], [6])
  """
  return x[:, :-horizon], x[:, -horizon:]

# %%
# Test out the window labelling function
test_window, test_label = get_labelled_windows(tf.expand_dims(tf.range(8)+1, axis=0), horizon=HORIZON)
print(f"Window: {tf.squeeze(test_window).numpy()} -> Label: {tf.squeeze(test_label).numpy()}")
# Out:
# Window: [1 2 3 4 5 6 7] -> Label: 8

# %%
def make_windows(x, window_size=7, horizon=1):
  """
  Turns a 1D array into a 2D array of sequential windows of window_size.
  """
  # 1. Create a window of specific window_size (add the horizon on the end for later labelling)
  window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
  # print(f"Window step:\n {window_step}")

  # 2. Create a 2D array of multiple window steps (minus 1 to account for 0 indexing)
  window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T # create 2D array of windows of size window_size
  # print(f"Window indexes:\n {window_indexes[:3], window_indexes[-3:], window_indexes.shape}")

  # 3. Index on the target array (time series) with 2D array of multiple window steps
  windowed_array = x[window_indexes]

  # 4. Get the labelled windows
  windows, labels = get_labelled_windows(windowed_array, horizon=horizon)

  return windows, labels

# %%
import numpy as np
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [50 53 57 52 58 55 60] -> Label: [56]
# Window: [53 57 52 58 55 60 56] -> Label: [59]
# Window: [57 52 58 55 60 56 59] -> Label: [62]

# %%
# View the last 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i-3]} -> Label: {full_labels[i-3]}")
# Out:
# Window: [78 81 85 88 85 82 79] -> Label: [82]
# Window: [81 85 88 85 82 79 82] -> Label: [85]
# Window: [85 88 85 82 79 82 85] -> Label: [88]

# %%
# Make the train/test splits
def make_train_test_splits(windows, labels, test_split=0.2):
  """
  Splits matching pairs of windows and labels into train and test splits.
  """
  split_size = int(len(windows) * (1-test_split)) # this will default to 80% train/20% test
  train_windows = windows[:split_size]
  train_labels = labels[:split_size]
  test_windows = windows[split_size:]
  test_labels = labels[split_size:]
  return train_windows, test_windows, train_labels, test_labels

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
from tensorflow.keras import layers
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1)) # add an extra dimension for timesteps
print(f"Original shape: {x.shape}") # (WINDOW_SIZE)
print(f"Expanded shape: {expand_dims_layer(x).shape}") # (WINDOW_SIZE, input_dim)
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[50]
#  [53]
#  [57]
#  [52]
#  [58]
#  [55]
#  [60]]

# %% [markdown]
# ### Modelling

# %%
import os
def create_model_checkpoint(model_name, save_path="model_experiments"):
  return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name),
                                            verbose=0,
                                            save_best_only=True)

# %%
tf.random.set_seed(42)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs) # expand input dimension to be compatible with LSTM
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x) # this layer will error if the inputs are not the right shape
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model = tf.keras.Model(inputs=inputs, outputs=output, name="model_5_lstm")

# Compile model
model.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Seems when saving the model several warnings are appearing: https://github.com/tensorflow/tensorflow/issues/47554
model.fit(train_windows,
            train_labels,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# Epoch 1/50
# 2/2 [==============================] - 5s 3s/step - loss: 72.7753 - val_loss: 80.8499
# Epoch 2/50
# 2/2 [==============================] - 2s 2s/step - loss: 71.2390 - val_loss: 79.0708
# Epoch 3/50
# 2/2 [==============================] - 2s 2s/step - loss: 69.6597 - val_loss: 77.1807
# Epoch 4/50
# 2/2 [==============================] - 2s 2s/step - loss: 67.9392 - val_loss: 75.1307
# Epoch 5/50
# 2/2 [==============================] - 2s 2s/step - loss: 66.0591 - val_loss: 72.8999
# Epoch 6/50
# 2/2 [==============================] - 2s 2s/step - loss: 64.0804 - val_loss: 70.4869
# Epoch 7/50
# 2/2 [==============================] - 2s 2s/step - loss: 61.9905 - val_loss: 67.6906
# Epoch 8/50
# 2/2 [==============================] - 2s 2s/step - loss: 59.5841 - val_loss: 64.2451
# Epoch 9/50
# 2/2 [==============================] - 2s 2s/step - loss: 56.8042 - val_loss: 60.3166
# Epoch 10/50
# 2/2 [==============================] - 2s 2s/step - loss: 53.6042 - val_loss: 56.4461
# Epoch 11/50
# 2/2 [==============================] - 2s 2s/step - loss: 50.1877 - val_loss: 52.8277
# Epoch 12/50
# 2/2 [==============================] - 2s 2s/step - loss: 46.6903 - val_loss: 49.3281
# Epoch 13/50
# 2/2 [==============================] - 2s 2s/step - loss: 43.4646 - val_loss: 45.9888
# Epoch 14/50
# 2/2 [==============================] - 3s 3s/step - loss: 40.4937 - val_loss: 42.7171
# Epoch 15/50
# 2/2 [==============================] - 4s 4s/step - loss: 37.6333 - val_loss: 39.1378
# Epoch 16/50
# 2/2 [==============================] - 2s 2s/step - loss: 34.5538 - val_loss: 35.0913
# Epoch 17/50
# 2/2 [==============================] - 2s 2s/step - loss: 31.1905 - val_loss: 30.8591
# Epoch 18/50
# 2/2 [==============================] - 2s 2s/step - loss: 27.4546 - val_loss: 26.8323
# Epoch 19/50
# 2/2 [==============================] - 2s 2s/step - loss: 23.8098 - val_loss: 23.1695
# Epoch 20/50
# 2/2 [==============================] - 2s 2s/step - loss: 20.4257 - val_loss: 19.6537
# Epoch 21/50
# 2/2 [==============================] - 2s 2s/step - loss: 17.1651 - val_loss: 15.9439
# Epoch 22/50
# 2/2 [==============================] - 2s 2s/step - loss: 13.7338 - val_loss: 11.6560
# Epoch 23/50
# 2/2 [==============================] - 2s 2s/step - loss: 9.6292 - val_loss: 6.6954
# Epoch 24/50
# 2/2 [==============================] - 2s 2s/step - loss: 5.7494 - val_loss: 3.5512
# Epoch 25/50
# 2/2 [==============================] - 0s 30ms/step - loss: 3.6472 - val_loss: 4.7002
# Epoch 26/50
# 2/2 [==============================] - 0s 30ms/step - loss: 4.6616 - val_loss: 7.3227
# Epoch 27/50
# 2/2 [==============================] - 0s 30ms/step - loss: 6.1696 - val_loss: 8.0675
# Epoch 28/50
# 2/2 [==============================] - 0s 29ms/step - loss: 6.3971 - val_loss: 7.1827
# Epoch 29/50
# 2/2 [==============================] - 0s 29ms/step - loss: 5.6406 - val_loss: 5.4230
# Epoch 30/50
# 2/2 [==============================] - 0s 29ms/step - loss: 4.4223 - val_loss: 3.9257
# Epoch 31/50
# 2/2 [==============================] - 2s 2s/step - loss: 3.7699 - val_loss: 3.0261
# Epoch 32/50
# 2/2 [==============================] - 2s 2s/step - loss: 3.7385 - val_loss: 2.9281
# Epoch 33/50
# 2/2 [==============================] - 2s 2s/step - loss: 4.0330 - val_loss: 2.9150
# Epoch 34/50
# 2/2 [==============================] - 2s 2s/step - loss: 3.9573 - val_loss: 2.9101
# Epoch 35/50
# 2/2 [==============================] - 2s 2s/step - loss: 4.0562 - val_loss: 2.9081
# Epoch 36/50
# 2/2 [==============================] - 0s 61ms/step - loss: 4.0728 - val_loss: 2.9085
# Epoch 37/50
# 2/2 [==============================] - 0s 64ms/step - loss: 4.0463 - val_loss: 2.9104
# Epoch 38/50
# 2/2 [==============================] - 0s 46ms/step - loss: 3.9797 - val_loss: 2.9132
# Epoch 39/50
# 2/2 [==============================] - 0s 41ms/step - loss: 3.9164 - val_loss: 2.9161
# Epoch 40/50
# 2/2 [==============================] - 0s 41ms/step - loss: 3.8730 - val_loss: 2.9192
# Epoch 41/50
# 2/2 [==============================] - 0s 41ms/step - loss: 3.8060 - val_loss: 3.0000
# Epoch 42/50
# 2/2 [==============================] - 0s 41ms/step - loss: 3.7565 - val_loss: 3.1299
# Epoch 43/50
# 2/2 [==============================] - 0s 42ms/step - loss: 3.8687 - val_loss: 3.4986
# Epoch 44/50
# 2/2 [==============================] - 0s 60ms/step - loss: 3.7651 - val_loss: 3.6810
# Epoch 45/50
# 2/2 [==============================] - 0s 61ms/step - loss: 3.7882 - val_loss: 3.7421
# Epoch 46/50
# 2/2 [==============================] - 0s 47ms/step - loss: 3.7945 - val_loss: 3.6878
# Epoch 47/50
# 2/2 [==============================] - 0s 44ms/step - loss: 3.7799 - val_loss: 3.5601
# Epoch 48/50
# 2/2 [==============================] - 0s 63ms/step - loss: 3.7646 - val_loss: 3.3592
# Epoch 49/50
# 2/2 [==============================] - 0s 55ms/step - loss: 3.7774 - val_loss: 3.1786
# Epoch 50/50
# 2/2 [==============================] - 0s 58ms/step - loss: 3.8013 - val_loss: 3.0802

# %%
# Load in best performing model
model = tf.keras.models.load_model("/content/model_experiments/model_5_lstm/")
model.evaluate(test_windows, test_labels)
# Out:
# 1/1 [==============================] - 0s 239ms/step - loss: 2.9081
# 2.9081106185913086

# %%
def make_preds(model, input_data):
  """
  Uses model to make predictions on input_data.

  Parameters
  ----------
  model: trained model
  input_data: windowed input data (same kind of data model was trained on)

  Returns model predictions on input_data.
  """
  forecast = model.predict(input_data)
  return tf.squeeze(forecast) # return 1D array of predictions

# %%
# Get forecast predictions
model_preds = make_preds(model,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 200ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([82.182335, 81.88345 , 81.745766, 82.483055, 83.88296 , 84.61434 ,
#        85.9674  , 85.871315], dtype=float32)>

# %%
# Evaluate results for model 2 predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels), # remove 1 dimension of test labels
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 2.9081106,
#  'mse': 11.539997,
#  'rmse': 3.397057,
#  'mape': 3.451173,
#  'mase': 0.9693702}

# %%
naive_results
# Out:
# {'mae': 3.1111112,
#  'mse': 9.777778,
#  'rmse': 3.1269438,
#  'mape': 3.711237,
#  'mase': 0.9955556}

# %%
plt.figure(figsize=(10, 7))
# Account for the test_window offset
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Prediction

# %%
# Add windowed columns
lumina_df = lumina.copy()
for i in range(WINDOW_SIZE):
  lumina_df[f"Stock_Price+{i+1}"] = lumina_df["Stock_Price"].shift(periods=i+1)
lumina_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08           56           60.0           55.0           58.0
# 2024-01-09           59           56.0           60.0           55.0
# 2024-01-10           62           59.0           56.0           60.0
# 2024-01-11           65           62.0           59.0           56.0
# 2024-01-12           61           65.0           62.0           59.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08           52.0           57.0           53.0           50.0
# 2024-01-09           58.0           52.0           57.0           53.0
# 2024-01-10           55.0           58.0           52.0           57.0
# 2024-01-11           60.0           55.0           58.0           52.0
# 2024-01-12           56.0           60.0           55.0           58.0

# %%
# Make features and labels
X = lumina_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = lumina_df.dropna()["Stock_Price"].to_numpy()

# %%
tf.random.set_seed(42)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs) # expand input dimension to be compatible with LSTM
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x) # this layer will error if the inputs are not the right shape
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model = tf.keras.Model(inputs=inputs, outputs=output, name="model_5_lstm")

# Compile model
model.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Seems when saving the model several warnings are appearing: https://github.com/tensorflow/tensorflow/issues/47554
model.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 3s 985ms/step - loss: 67.0897 - val_loss: 69.8491
# Epoch 2/50
# 3/3 [==============================] - 2s 960ms/step - loss: 62.4824 - val_loss: 65.1052
# Epoch 3/50
# 3/3 [==============================] - 2s 863ms/step - loss: 58.5395 - val_loss: 61.1980
# Epoch 4/50
# 3/3 [==============================] - 3s 1s/step - loss: 55.3912 - val_loss: 58.0755
# Epoch 5/50
# 3/3 [==============================] - 2s 1s/step - loss: 52.5578 - val_loss: 54.7438
# Epoch 6/50
# 3/3 [==============================] - 2s 815ms/step - loss: 49.3551 - val_loss: 50.3851
# Epoch 7/50
# 3/3 [==============================] - 2s 878ms/step - loss: 45.1986 - val_loss: 44.2144
# Epoch 8/50
# 3/3 [==============================] - 2s 877ms/step - loss: 39.3618 - val_loss: 36.0209
# Epoch 9/50
# 3/3 [==============================] - 2s 1s/step - loss: 31.8473 - val_loss: 28.5968
# Epoch 10/50
# 3/3 [==============================] - 2s 805ms/step - loss: 25.5297 - val_loss: 22.9112
# Epoch 11/50
# 3/3 [==============================] - 2s 1s/step - loss: 20.3491 - val_loss: 17.2257
# Epoch 12/50
# 3/3 [==============================] - 2s 1s/step - loss: 14.9303 - val_loss: 10.6783
# Epoch 13/50
# 3/3 [==============================] - 2s 806ms/step - loss: 9.0413 - val_loss: 3.9907
# Epoch 14/50
# 3/3 [==============================] - 2s 1s/step - loss: 4.6509 - val_loss: 2.8453
# Epoch 15/50
# 3/3 [==============================] - 0s 18ms/step - loss: 3.3852 - val_loss: 5.6236
# Epoch 16/50
# 3/3 [==============================] - 0s 18ms/step - loss: 4.8466 - val_loss: 6.6256
# Epoch 17/50
# 3/3 [==============================] - 0s 24ms/step - loss: 5.1276 - val_loss: 5.5122
# Epoch 18/50
# 3/3 [==============================] - 0s 18ms/step - loss: 4.1591 - val_loss: 3.7585
# Epoch 19/50
# 3/3 [==============================] - 2s 815ms/step - loss: 3.4488 - val_loss: 2.2910
# Epoch 20/50
# 3/3 [==============================] - 0s 49ms/step - loss: 3.4508 - val_loss: 2.4597
# Epoch 21/50
# 3/3 [==============================] - 0s 28ms/step - loss: 3.7417 - val_loss: 2.4575
# Epoch 22/50
# 3/3 [==============================] - 4s 2s/step - loss: 3.6761 - val_loss: 2.2857
# Epoch 23/50
# 3/3 [==============================] - 0s 52ms/step - loss: 3.3248 - val_loss: 2.3861
# Epoch 24/50
# 3/3 [==============================] - 0s 58ms/step - loss: 3.2038 - val_loss: 3.3024
# Epoch 25/50
# 3/3 [==============================] - 0s 50ms/step - loss: 3.4529 - val_loss: 3.7071
# Epoch 26/50
# 3/3 [==============================] - 0s 83ms/step - loss: 3.5341 - val_loss: 3.4160
# Epoch 27/50
# 3/3 [==============================] - 0s 99ms/step - loss: 3.3942 - val_loss: 2.7493
# Epoch 28/50
# 3/3 [==============================] - 0s 73ms/step - loss: 3.2343 - val_loss: 2.3216
# Epoch 29/50
# 3/3 [==============================] - 3s 2s/step - loss: 3.2322 - val_loss: 2.2802
# Epoch 30/50
# 3/3 [==============================] - 2s 807ms/step - loss: 3.3366 - val_loss: 2.2783
# Epoch 31/50
# 3/3 [==============================] - 0s 17ms/step - loss: 3.2571 - val_loss: 2.2883
# Epoch 32/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3.1998 - val_loss: 2.4385
# Epoch 33/50
# 3/3 [==============================] - 0s 17ms/step - loss: 3.2175 - val_loss: 2.7612
# Epoch 34/50
# 3/3 [==============================] - 0s 17ms/step - loss: 3.2476 - val_loss: 2.7452
# Epoch 35/50
# 3/3 [==============================] - 0s 18ms/step - loss: 3.2365 - val_loss: 2.4613
# Epoch 36/50
# 3/3 [==============================] - 2s 804ms/step - loss: 3.2669 - val_loss: 2.2710
# Epoch 37/50
# 3/3 [==============================] - 2s 1s/step - loss: 3.2326 - val_loss: 2.2691
# Epoch 38/50
# 3/3 [==============================] - 0s 25ms/step - loss: 3.2475 - val_loss: 2.2908
# Epoch 39/50
# 3/3 [==============================] - 0s 21ms/step - loss: 3.2113 - val_loss: 2.3743
# Epoch 40/50
# 3/3 [==============================] - 0s 24ms/step - loss: 3.1940 - val_loss: 2.4715
# Epoch 41/50
# 3/3 [==============================] - 0s 35ms/step - loss: 3.2281 - val_loss: 2.4130
# Epoch 42/50
# 3/3 [==============================] - 0s 23ms/step - loss: 3.1997 - val_loss: 2.4633
# Epoch 43/50
# 3/3 [==============================] - 0s 21ms/step - loss: 3.2043 - val_loss: 2.4010
# Epoch 44/50
# 3/3 [==============================] - 0s 20ms/step - loss: 3.1999 - val_loss: 2.2812
# Epoch 45/50
# 3/3 [==============================] - 2s 901ms/step - loss: 3.1980 - val_loss: 2.2587
# Epoch 46/50
# 3/3 [==============================] - 2s 1s/step - loss: 3.2148 - val_loss: 2.2568
# Epoch 47/50
# 3/3 [==============================] - 0s 25ms/step - loss: 3.2132 - val_loss: 2.3090
# Epoch 48/50
# 3/3 [==============================] - 0s 34ms/step - loss: 3.1998 - val_loss: 2.3629
# Epoch 49/50
# 3/3 [==============================] - 0s 32ms/step - loss: 3.1964 - val_loss: 2.3597
# Epoch 50/50
# 3/3 [==============================] - 0s 33ms/step - loss: 3.1889 - val_loss: 2.4480

# %%
# How many timesteps to predict into the future?
INTO_FUTURE = 7 # since our stock price data is daily, this is for 14 days

# %%
# 1. Create function to make predictions into the future
def make_future_forecast(values, model, into_future, window_size=WINDOW_SIZE) -> list:
  """
  Makes future forecasts into_future steps after values ends.

  Returns future forecasts as list of floats.
  """
  # 2. Make an empty list for future forecasts/prepare data to forecast on
  future_forecast = []
  last_window = values[-WINDOW_SIZE:] # only want preds from the last window (this will get updated)

  # 3. Make INTO_FUTURE number of predictions, altering the data which gets predicted on each time
  for _ in range(into_future):

    # Predict on last window then append it again, again, again (model starts to make forecasts on its own forecasts)
    future_pred = model.predict(tf.expand_dims(last_window, axis=0))
    print(f"Predicting on: \n {last_window} -> Prediction: {tf.squeeze(future_pred).numpy()}\n")

    # Append predictions to future_forecast
    future_forecast.append(tf.squeeze(future_pred).numpy())
    # print(future_forecast)

    # Update last window with new pred and get WINDOW_SIZE most recent preds (model was trained on WINDOW_SIZE windows)
    last_window = np.append(last_window, future_pred)[-WINDOW_SIZE:]

  return future_forecast

# %%
def get_future_dates(start_date, into_future, offset=1):
  """
  Returns array of datetime values from ranging from start_date to start_date+horizon.

  start_date: date to start range (np.datetime64)
  into_future: number of days to add onto start date for range (int)
  offset: number of days to offset start_date by (default 1)
  """
  start_date = start_date + np.timedelta64(offset, "D") # specify start date, "D" stands for day
  end_date = start_date + np.timedelta64(into_future, "D") # specify end date
  return np.arange(start_date, end_date, dtype="datetime64[D]") # return a date range between start date and end date

# %%
# Last timestep of timesteps (currently in np.datetime64 format)
last_timestep = lumina.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next two weeks of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22'], dtype='datetime64[D]')

# %%
# Insert last timestep/final price so the graph doesn't look messed
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, lumina["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22'],
#        dtype='datetime64[D]'),
#  array([88.     , 88.80375, 88.94683, 89.16429, 89.81641, 91.41216,
#         92.9631 , 94.37761], dtype=float32))

# %%
# Make forecasts into future of the price of Bitcoin
# Note: if you're reading this at a later date, you may already be in the future, so the forecasts
# we're making may not actually be forecasts, if that's the case, readjust the training data.
future_forecast = make_future_forecast(values=y,
                                       model=model,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 277ms/step
# Predicting on:
#  [88 85 82 79 82 85 88] -> Prediction: 88.80374908447266
#
# 1/1 [==============================] - 0s 315ms/step
# Predicting on:
#  [85.         82.         79.         82.         85.         88.
#  88.80374908] -> Prediction: 88.94683074951172
#
# 1/1 [==============================] - 0s 40ms/step
# Predicting on:
#  [82.         79.         82.         85.         88.         88.80374908
#  88.94683075] -> Prediction: 89.16429138183594
#
# 1/1 [==============================] - 0s 33ms/step
# Predicting on:
#  [79.         82.         85.         88.         88.80374908 88.94683075
#  89.16429138] -> Prediction: 89.81640625
#
# 1/1 [==============================] - 0s 36ms/step
# Predicting on:
#  [82.         85.         88.         88.80374908 88.94683075 89.16429138
#  89.81640625] -> Prediction: 91.41216278076172
#
# 1/1 [==============================] - 0s 36ms/step
# Predicting on:
#  [85.         88.         88.80374908 88.94683075 89.16429138 89.81640625
#  91.41216278] -> Prediction: 92.96309661865234
#
# 1/1 [==============================] - 0s 36ms/step
# Predicting on:
#  [88.         88.80374908 88.94683075 89.16429138 89.81640625 91.41216278
#  92.96309662] -> Prediction: 94.37760925292969

# %%
# Plot future price predictions of Bitcoin
plt.figure(figsize=(10, 7))
plot_time_series(lumina.index, lumina["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")

# %% [markdown]
# ## Nexus

# %%
# Get date array
timesteps = nexus.index.to_numpy()
prices = nexus["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([120, 114, 127, 120, 124, 118, 122, 118, 115, 119]))

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [120 114 127 120 124 118 122] -> Label: [118]
# Window: [114 127 120 124 118 122 118] -> Label: [115]
# Window: [127 120 124 118 122 118 115] -> Label: [119]

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
from tensorflow.keras import layers
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1)) # add an extra dimension for timesteps
print(f"Original shape: {x.shape}") # (WINDOW_SIZE)
print(f"Expanded shape: {expand_dims_layer(x).shape}") # (WINDOW_SIZE, input_dim)
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[120]
#  [114]
#  [127]
#  [120]
#  [124]
#  [118]
#  [122]]

# %% [markdown]
# ### Modelling

# %%
tf.random.set_seed(42)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs) # expand input dimension to be compatible with LSTM
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x) # this layer will error if the inputs are not the right shape
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model = tf.keras.Model(inputs=inputs, outputs=output, name="model_5_lstm")

# Compile model
model.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Seems when saving the model several warnings are appearing: https://github.com/tensorflow/tensorflow/issues/47554
model.fit(train_windows,
            train_labels,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# Epoch 1/50
# 2/2 [==============================] - 5s 4s/step - loss: 102.4844 - val_loss: 90.0846
# Epoch 2/50
# 2/2 [==============================] - 3s 3s/step - loss: 99.5766 - val_loss: 86.9368
# Epoch 3/50
# 2/2 [==============================] - 3s 3s/step - loss: 96.1674 - val_loss: 83.7403
# Epoch 4/50
# 2/2 [==============================] - 2s 2s/step - loss: 92.9555 - val_loss: 80.2123
# Epoch 5/50
# 2/2 [==============================] - 3s 3s/step - loss: 88.8316 - val_loss: 75.0743
# Epoch 6/50
# 2/2 [==============================] - 4s 4s/step - loss: 82.6412 - val_loss: 68.2031
# Epoch 7/50
# 2/2 [==============================] - 3s 3s/step - loss: 75.4261 - val_loss: 61.3070
# Epoch 8/50
# 2/2 [==============================] - 3s 3s/step - loss: 68.7805 - val_loss: 54.3643
# Epoch 9/50
# 2/2 [==============================] - 3s 3s/step - loss: 61.5634 - val_loss: 46.3629
# Epoch 10/50
# 2/2 [==============================] - 4s 4s/step - loss: 52.7343 - val_loss: 38.5032
# Epoch 11/50
# 2/2 [==============================] - 2s 2s/step - loss: 44.1536 - val_loss: 31.8620
# Epoch 12/50
# 2/2 [==============================] - 3s 3s/step - loss: 35.8767 - val_loss: 24.9133
# Epoch 13/50
# 2/2 [==============================] - 3s 3s/step - loss: 27.5139 - val_loss: 16.7213
# Epoch 14/50
# 2/2 [==============================] - 2s 2s/step - loss: 19.1483 - val_loss: 8.0559
# Epoch 15/50
# 2/2 [==============================] - 2s 2s/step - loss: 10.2318 - val_loss: 2.6111
# Epoch 16/50
# 2/2 [==============================] - 0s 61ms/step - loss: 3.3744 - val_loss: 8.6440
# Epoch 17/50
# 2/2 [==============================] - 0s 41ms/step - loss: 6.5155 - val_loss: 11.8378
# Epoch 18/50
# 2/2 [==============================] - 0s 62ms/step - loss: 9.0123 - val_loss: 12.2334
# Epoch 19/50
# 2/2 [==============================] - 0s 63ms/step - loss: 8.9107 - val_loss: 10.8578
# Epoch 20/50
# 2/2 [==============================] - 0s 46ms/step - loss: 7.0643 - val_loss: 8.1749
# Epoch 21/50
# 2/2 [==============================] - 0s 67ms/step - loss: 4.4189 - val_loss: 4.7230
# Epoch 22/50
# 2/2 [==============================] - 0s 44ms/step - loss: 3.2816 - val_loss: 2.7707
# Epoch 23/50
# 2/2 [==============================] - 3s 3s/step - loss: 3.6601 - val_loss: 2.4671
# Epoch 24/50
# 2/2 [==============================] - 3s 3s/step - loss: 4.4133 - val_loss: 2.4669
# Epoch 25/50
# 2/2 [==============================] - 0s 113ms/step - loss: 4.2072 - val_loss: 2.7094
# Epoch 26/50
# 2/2 [==============================] - 0s 51ms/step - loss: 3.4066 - val_loss: 3.4430
# Epoch 27/50
# 2/2 [==============================] - 0s 56ms/step - loss: 2.8670 - val_loss: 4.1904
# Epoch 28/50
# 2/2 [==============================] - 0s 91ms/step - loss: 2.8738 - val_loss: 5.1926
# Epoch 29/50
# 2/2 [==============================] - 0s 102ms/step - loss: 3.1365 - val_loss: 5.4943
# Epoch 30/50
# 2/2 [==============================] - 0s 85ms/step - loss: 3.2408 - val_loss: 5.2122
# Epoch 31/50
# 2/2 [==============================] - 0s 158ms/step - loss: 3.0123 - val_loss: 4.3697
# Epoch 32/50
# 2/2 [==============================] - 0s 69ms/step - loss: 2.8197 - val_loss: 3.8267
# Epoch 33/50
# 2/2 [==============================] - 0s 105ms/step - loss: 2.8550 - val_loss: 3.4922
# Epoch 34/50
# 2/2 [==============================] - 0s 50ms/step - loss: 2.9649 - val_loss: 3.2984
# Epoch 35/50
# 2/2 [==============================] - 0s 70ms/step - loss: 3.0248 - val_loss: 3.3728
# Epoch 36/50
# 2/2 [==============================] - 0s 74ms/step - loss: 2.9459 - val_loss: 3.6443
# Epoch 37/50
# 2/2 [==============================] - 0s 51ms/step - loss: 2.8662 - val_loss: 3.9692
# Epoch 38/50
# 2/2 [==============================] - 0s 52ms/step - loss: 2.7821 - val_loss: 4.3256
# Epoch 39/50
# 2/2 [==============================] - 0s 87ms/step - loss: 2.8330 - val_loss: 4.6560
# Epoch 40/50
# 2/2 [==============================] - 0s 179ms/step - loss: 2.9194 - val_loss: 4.6636
# Epoch 41/50
# 2/2 [==============================] - 0s 53ms/step - loss: 2.8959 - val_loss: 4.1789
# Epoch 42/50
# 2/2 [==============================] - 0s 91ms/step - loss: 2.8763 - val_loss: 3.8312
# Epoch 43/50
# 2/2 [==============================] - 0s 115ms/step - loss: 2.8330 - val_loss: 3.7337
# Epoch 44/50
# 2/2 [==============================] - 0s 49ms/step - loss: 2.8629 - val_loss: 3.7300
# Epoch 45/50
# 2/2 [==============================] - 0s 67ms/step - loss: 2.8582 - val_loss: 3.7520
# Epoch 46/50
# 2/2 [==============================] - 0s 55ms/step - loss: 2.9013 - val_loss: 3.9300
# Epoch 47/50
# 2/2 [==============================] - 0s 61ms/step - loss: 2.8259 - val_loss: 4.0658
# Epoch 48/50
# 2/2 [==============================] - 0s 98ms/step - loss: 2.8011 - val_loss: 4.1713
# Epoch 49/50
# 2/2 [==============================] - 0s 80ms/step - loss: 2.7999 - val_loss: 4.2271
# Epoch 50/50
# 2/2 [==============================] - 0s 43ms/step - loss: 2.8160 - val_loss: 4.2300

# %%
# Load in best performing model
model = tf.keras.models.load_model("/content/model_experiments/model_5_lstm/")
model.evaluate(test_windows, test_labels)
# Out:
# 1/1 [==============================] - 0s 306ms/step - loss: 2.4669
# 2.466891288757324

# %%
# Get forecast predictions
model_preds = make_preds(model,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 256ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([108.10307 , 107.66048 , 106.98642 , 106.40478 , 105.81772 ,
#        105.622215, 103.33839 , 101.86129 ], dtype=float32)>

# %%
# Evaluate results for model 2 predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels), # remove 1 dimension of test labels
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 2.4668903,
#  'mse': 9.243593,
#  'rmse': 3.0403278,
#  'mape': 2.3457067,
#  'mase': 0.71950966}

# %%
plt.figure(figsize=(10, 7))
# Account for the test_window offset
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Predicition

# %%
# Add windowed columns
nexus_df = nexus.copy()
for i in range(WINDOW_SIZE):
  nexus_df[f"Stock_Price+{i+1}"] = nexus_df["Stock_Price"].shift(periods=i+1)
nexus_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08          118          122.0          118.0          124.0
# 2024-01-09          115          118.0          122.0          118.0
# 2024-01-10          119          115.0          118.0          122.0
# 2024-01-11          123          119.0          115.0          118.0
# 2024-01-12          120          123.0          119.0          115.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08          120.0          127.0          114.0          120.0
# 2024-01-09          124.0          120.0          127.0          114.0
# 2024-01-10          118.0          124.0          120.0          127.0
# 2024-01-11          122.0          118.0          124.0          120.0
# 2024-01-12          118.0          122.0          118.0          124.0

# %%
# Make features and labels
X = nexus_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = nexus_df.dropna()["Stock_Price"].to_numpy()

# %%
model.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(
50
# 3/3 [==============================] - 0s 29ms/step - loss: 2.8171 - val_loss: 4.0404
# Epoch 34/50
# 3/3 [==============================] - 0s 28ms/step - loss: 2.7706 - val_loss: 4.3827
# Epoch 35/50
# 3/3 [==============================] - 0s 27ms/step - loss: 2.8791 - val_loss: 4.1981
# Epoch 36/50
# 3/3 [==============================] - 0s 36ms/step - loss: 2.7048 - val_loss: 3.7950
# Epoch 37/50
# 3/3 [==============================] - 0s 26ms/step - loss: 2.8397 - val_loss: 4.2773
# Epoch 38/50
# 3/3 [==============================] - 0s 32ms/step - loss: 2.8809 - val_loss: 4.3453
# Epoch 39/50
# 3/3 [==============================] - 0s 26ms/step - loss: 2.7922 - val_loss: 3.7004
# Epoch 40/50
# 3/3 [==============================] - 0s 34ms/step - loss: 2.9528 - val_loss: 3.5748
# Epoch 41/50
# 3/3 [==============================] - 0s 32ms/step - loss: 2.8976 - val_loss: 4.6284
# Epoch 42/50
# 3/3 [==============================] - 0s 25ms/step - loss: 2.9904 - val_loss: 4.2520
# Epoch 43/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.8360 - val_loss: 3.2899
# Epoch 44/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3.1769 - val_loss: 3.2604
# Epoch 45/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.9125 - val_loss: 4.2429
# Epoch 46/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.9211 - val_loss: 4.9306
# Epoch 47/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.9734 - val_loss: 3.8726
# Epoch 48/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7824 - val_loss: 3.6163
# Epoch 49/50
# 3/3 [==============================] - 0s 19ms/step - loss: 2.8562 - val_loss: 3.8255
# Epoch 50/50
# 3/3 [==============================] - 0s 19ms/step - loss: 2.8160 - val_loss: 4.0123

# %%
# How many timesteps to predict into the future?
INTO_FUTURE = 4 # since our stock price data is daily, this is for 14 days

# %%
# Make forecasts into future of the price of Bitcoin
# Note: if you're reading this at a later date, you may already be in the future, so the forecasts
# we're making may not actually be forecasts, if that's the case, readjust the training data.
future_forecast = make_future_forecast(values=y,
                                       model=model,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 76ms/step
# Predicting on:
#  [108 105 108 104 100 103 106] -> Prediction: 104.602783203125
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7eff1d775bd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 533ms/step
# Predicting on:
#  [105.        108.        104.        100.        103.        106.
#  104.6027832] -> Prediction: 103.43704223632812
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [108.         104.         100.         103.         106.
#  104.6027832  103.43704224] -> Prediction: 103.51666259765625
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [104.         100.         103.         106.         104.6027832
#  103.43704224 103.5166626 ] -> Prediction: 102.41792297363281

# %%
# Last timestep of timesteps (currently in np.datetime64 format)
last_timestep = nexus.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next two weeks of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19'],
#       dtype='datetime64[D]')

# %%
# Insert last timestep/final price so the graph doesn't look messed
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, nexus["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19'], dtype='datetime64[D]'),
#  array([106.     , 104.60278, 103.43704, 103.51666, 102.41792],
#        dtype=float32))

# %%
# Plot future price predictions of Bitcoin
plt.figure(figsize=(10, 7))
plot_time_series(nexus.index, nexus["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")

# %% [markdown]
# ## Quantumize

# %%
# Get date array
timesteps = quantumize.index.to_numpy()
prices = quantumize["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([80, 83, 86, 84, 81, 79, 82, 85, 87, 89]))

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [80 83 86 84 81 79 82] -> Label: [85]
# Window: [83 86 84 81 79 82 85] -> Label: [87]
# Window: [86 84 81 79 82 85 87] -> Label: [89]

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1)) # add an extra dimension for timesteps
print(f"Original shape: {x.shape}") # (WINDOW_SIZE)
print(f"Expanded shape: {expand_dims_layer(x).shape}") # (WINDOW_SIZE, input_dim)
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[80]
#  [83]
#  [86]
#  [84]
#  [81]
#  [79]
#  [82]]

# %% [markdown]
# ### Modelling

# %%
tf.random.set_seed(42)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs) # expand input dimension to be compatible with LSTM
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x) # this layer will error if the inputs are not the right shape
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model = tf.keras.Model(inputs=inputs, outputs=output, name="model_5_lstm")

# Compile model
model.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Seems when saving the model several warnings are appearing: https://github.com/tensorflow/tensorflow/issues/47554
model.fit(train_windows,
            train_labels,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# Epoch 1/50
# 2/2 [==============================] - 4s 2s/step - loss: 71.9224 - val_loss: 70.7711
# Epoch 2/50
# 2/2 [==============================] - 2s 2s/step - loss: 68.7499 - val_loss: 66.2385
# Epoch 3/50
# 2/2 [==============================] - 2s 2s/step - loss: 64.3069 - val_loss: 60.5315
# Epoch 4/50
# 2/2 [==============================] - 2s 2s/step - loss: 58.7081 - val_loss: 53.9347
# Epoch 5/50
# 2/2 [==============================] - 2s 2s/step - loss: 52.0214 - val_loss: 46.9620
# Epoch 6/50
# 2/2 [==============================] - 2s 2s/step - loss: 45.2111 - val_loss: 40.5372
# Epoch 7/50
# 2/2 [==============================] - 40s 40s/step - loss: 38.6642 - val_loss: 35.2617
# Epoch 8/50
# 2/2 [==============================] - 2s 2s/step - loss: 32.8619 - val_loss: 31.1205
# Epoch 9/50
# 2/2 [==============================] - 2s 2s/step - loss: 28.1743 - val_loss: 27.6308
# Epoch 10/50
# 2/2 [==============================] - 2s 2s/step - loss: 24.3702 - val_loss: 24.3379
# Epoch 11/50
# 2/2 [==============================] - 2s 2s/step - loss: 20.9414 - val_loss: 21.0340
# Epoch 12/50
# 2/2 [==============================] - 2s 2s/step - loss: 17.5558 - val_loss: 17.6348
# Epoch 13/50
# 2/2 [==============================] - 2s 2s/step - loss: 14.0619 - val_loss: 14.0454
# Epoch 14/50
# 2/2 [==============================] - 2s 2s/step - loss: 10.3996 - val_loss: 10.1849
# Epoch 15/50
# 2/2 [==============================] - 2s 2s/step - loss: 6.8070 - val_loss: 6.1241
# Epoch 16/50
# 2/2 [==============================] - 3s 3s/step - loss: 4.4100 - val_loss: 3.6502
# Epoch 17/50
# 2/2 [==============================] - 2s 2s/step - loss: 4.1320 - val_loss: 3.6177
# Epoch 18/50
# 2/2 [==============================] - 0s 31ms/step - loss: 4.0989 - val_loss: 4.4490
# Epoch 48/50
# 2/2 [==============================] - 0s 30ms/step - loss: 4.0898 - val_loss: 4.4326
# Epoch 49/50
# 2/2 [==============================] - 0s 30ms/step - loss: 4.0861 - val_loss: 4.4148
# Epoch 50/50
# 2/2 [==============================] - 0s 33ms/step - loss: 4.0835 - val_loss: 4.3713

# %%
# Load in best performing model
model = tf.keras.models.load_model("/content/model_experiments/model_5_lstm/")
model.evaluate(test_windows, test_labels)
# Out:
# 1/1 [==============================] - 0s 235ms/step - loss: 3.6177
# 3.617682456970215

# %%
# Get forecast predictions
model_preds = make_preds(model,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 179ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([78.877846, 80.81806 , 82.9371  , 84.1267  , 84.19155 , 85.14917 ,
#        85.04083 , 84.3196  ], dtype=float32)>

# %%
# Evaluate results for model 2 predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels), # remove 1 dimension of test labels
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 3.6176805,
#  'mse': 16.131536,
#  'rmse': 4.0164084,
#  'mape': 4.4408755,
#  'mase': 1.4896332}

# %%
plt.figure(figsize=(10, 7))
# Account for the test_window offset
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Prediction

# %%
# Add windowed columns
quantumize_df = quantumize.copy()
for i in range(WINDOW_SIZE):
  quantumize_df[f"Stock_Price+{i+1}"] = quantumize_df["Stock_Price"].shift(periods=i+1)
quantumize_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08           85           82.0           79.0           81.0
# 2024-01-09           87           85.0           82.0           79.0
# 2024-01-10           89           87.0           85.0           82.0
# 2024-01-11           92           89.0           87.0           85.0
# 2024-01-12           94           92.0           89.0           87.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08           84.0           86.0           83.0           80.0
# 2024-01-09           81.0           84.0           86.0           83.0
# 2024-01-10           79.0           81.0           84.0           86.0
# 2024-01-11           82.0           79.0           81.0           84.0
# 2024-01-12           85.0           82.0           79.0           81.0

# %%
# Make features and labels
X = quantumize_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = quantumize_df.dropna()["Stock_Price"].to_numpy()

# %%
model.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels))
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 45ms/step - loss: 4.5926 - val_loss: 4.3480
# Epoch 2/50
# 3/3 [==============================] - 0s 17ms/step - loss: 4.5472 - val_loss: 4.0951
# Epoch 3/50
# 3/3 [==============================] - 0s 17ms/step - loss: 4.4699 - val_loss: 4.2799
# Epoch 4/50
# 3/3 [==============================] - 0s 17ms/step - loss: 4.3023 - val_loss: 4.2020
# Epoch 5/50
# 3/3 [==============================] - 0s 16ms/step - loss: 4.1454 - val_loss: 4.2488
# Epoch 6/50
# 3/3 [==============================] - 0s 16ms/step - loss: 4.0129 - val_loss: 4.9989
# Epoch 7/50
# 3/3 [==============================] - 0s 16ms/step - loss: 4.1341 - val_loss: 4.8094
# Epoch 8/50
# 3/3 [==============================] - 0s 16ms/step - loss: 3
50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.9055 - val_loss: 5.6305
# Epoch 50/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.9917 - val_loss: 5.4099

# %%
# How many timesteps to predict into the future?
INTO_FUTURE = 7 # since our stock price data is daily, this is for 14 days

# %%
# Make forecasts into future of the price of Bitcoin
# Note: if you're reading this at a later date, you may already be in the future, so the forecasts
# we're making may not actually be forecasts, if that's the case, readjust the training data.
future_forecast = make_future_forecast(values=y,
                                       model=model,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Predicting on:
#  [84 87 85 82 80 78 81] -> Prediction: 84.89266967773438
#
# 1/1 [==============================] - 0s 187ms/step
# Predicting on:
#  [87.         85.         82.         80.         78.         81.
#  84.89266968] -> Prediction: 85.57278442382812
#
# 1/1 [==============================] - 0s 28ms/step
# Predicting on:
#  [85.         82.         80.         78.         81.         84.89266968
#  85.57278442] -> Prediction: 82.08373260498047
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [82.         80.         78.         81.         84.89266968 85.57278442
#  82.0837326 ] -> Prediction: 80.54603576660156
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [80.         78.         81.         84.89266968 85.57278442 82.0837326
#  80.54603577] -> Prediction: 82.21100616455078
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [78.         81.         84.89266968 85.57278442 82.0837326  80.54603577
#  82.21100616] -> Prediction: 82.06742858886719
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [81.         84.89266968 85.57278442 82.0837326  80.54603577 82.21100616
#  82.06742859] -> Prediction: 81.72160339355469

# %%
# Last timestep of timesteps (currently in np.datetime64 format)
last_timestep = quantumize.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next two weeks of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22'], dtype='datetime64[D]')

# %%
# Insert last timestep/final price so the graph doesn't look messed
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, quantumize["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22'],
#        dtype='datetime64[D]'),
#  array([81.      , 84.89267 , 85.572784, 82.08373 , 80.546036, 82.211006,
#         82.06743 , 81.7216  ], dtype=float32))

# %%
# Plot future price predictions
plt.figure(figsize=(10, 7))
plot_time_series(quantumize.index, quantumize["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")

# %% [markdown]
# ## Synthify

# %%
# Get date array
timesteps = synthify.index.to_numpy()
prices = synthify["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([150, 156, 161, 155, 150, 152, 148, 151, 153, 156]))

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [150 156 161 155 150 152 148] -> Label: [151]
# Window: [156 161 155 150 152 148 151] -> Label: [153]
# Window: [161 155 150 152 148 151 153] -> Label: [156]

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
from tensorflow.keras import layers
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1)) # add an extra dimension for timesteps
print(f"Original shape: {x.shape}") # (WINDOW_SIZE)
print(f"Expanded shape: {expand_dims_layer(x).shape}") # (WINDOW_SIZE, input_dim)
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[150]
#  [156]
#  [161]
#  [155]
#  [150]
#  [152]
#  [148]]

# %% [markdown]
# ### Modelling

# %%
tf.random.set_seed(42)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs) # expand input dimension to be compatible with LSTM
x = layers.LSTM(64, activation="relu", return_sequences=True)(x) # this layer will error if the inputs are not the right shape
x = tf.keras.layers.LSTM(32, activation="relu")(x)
x = layers.Dense(16, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model = tf.keras.Model(inputs=inputs, outputs=output, name="model_lstm_AR")

# Compile model
model.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam(0.010))

# Seems when saving the model several warnings are appearing: https://github.com/tensorflow/tensorflow/issues/47554
model.fit(train_windows,
            train_labels,
            epochs=100,
            verbose
# 1/1 [==============================] - 0s 40ms/step - loss: 4.6327 - val_loss: 7.2103
# Epoch 89/100
# 1/1 [==============================] - 0s 39ms/step - loss: 4.8057 - val_loss: 7.2357
# Epoch 90/100
# 1/1 [==============================] - 0s 41ms/step - loss: 4.7787 - val_loss: 7.5275
# Epoch 91/100
# 1/1 [==============================] - 0s 43ms/step - loss: 4.6102 - val_loss: 8.1282
# Epoch 92/100
# 1/1 [==============================] - 0s 42ms/step - loss: 4.7333 - val_loss: 8.0036
# Epoch 93/100
# 1/1 [==============================] - 0s 40ms/step - loss: 4.6843 - val_loss: 7.4708
# Epoch 94/100
# 1/1 [==============================] - 0s 40ms/step - loss: 4.6044 - val_loss: 7.2463
# Epoch 95/100
# 1/1 [==============================] - 0s 43ms/step - loss: 4.7271 - val_loss: 7.3191
# Epoch 96/100
# 1/1 [==============================] - 0s 40ms/step - loss: 4.6653 - val_loss: 7.7832
# Epoch 97/100
# 1/1 [==============================] - 0s 40ms/step - loss: 4.6025 - val_loss: 7.8877
# Epoch 98/100
# 1/1 [==============================] - 0s 38ms/step - loss: 4.6359 - val_loss: 7.4910
# Epoch 99/100
# 1/1 [==============================] - 0s 70ms/step - loss: 4.5756 - val_loss: 7.3553
# Epoch 100/100
# 1/1 [==============================] - 0s 40ms/step - loss: 4.6029 - val_loss: 7.5164

# %%
# Load in best performing model
model = tf.keras.models.load_model("/content/model_experiments/model_lstm_AR/")
model.evaluate(test_windows, test_labels)
# Out:
# 1/1 [==============================] - 0s 335ms/step - loss: 6.8926
# 6.892587661743164

# %%
# Get forecast predictions
model_preds = make_preds(model,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 287ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([154.7576 , 151.9358 , 150.32239, 149.92265, 148.9485 , 149.1496 ,
#        150.02974, 151.66989], dtype=float32)>

# %%
# Evaluate results for model 2 predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels), # remove 1 dimension of test labels
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 6.8925896,
#  'mse': 63.910564,
#  'rmse': 7.994408,
#  'mape': 4.623914,
#  'mase': 2.29753}

# %%
plt.figure(figsize=(10, 7))
# Account for the test_window offset
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Predicition

# %%
# Add windowed columns
synthify_df = synthify.copy()
for i in range(WINDOW_SIZE):
  synthify_df[f"Stock_Price+{i+1}"] = synthify_df["Stock_Price"].shift(periods=i+1)
synthify_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08          151          148.0          152.0          150.0
# 2024-01-09          153          151.0          148.0          152.0
# 2024-01-10          156          153.0          151.0          148.0
# 2024-01-11          160          156.0          153.0          151.0
# 2024-01-12          163          160.0          156.0          153.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08          155.0          161.0          156.0          150.0
# 2024-01-09          150.0          155.0          161.0          156.0
# 2024-01-10          152.0          150.0          155.0          161.0
# 2024-01-11          148.0          152.0          150.0          155.0
# 2024-01-12          151.0          148.0          152.0          150.0

# %%
# Make features and labels
X = synthify_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = synthify_df.dropna()["Stock_Price"].to_numpy()

# %%
model.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(
#  156.44226074 158.42027283] -> Prediction: 160.0012969970703
#
# 1/1 [==============================] - 0s 51ms/step
# Predicting on:
#  [155.         158.         161.         154.51678467 156.44226074
#  158.42027283 160.001297  ] -> Prediction: 161.223876953125
#
# 1/1 [==============================] - 0s 39ms/step
# Predicting on:
#  [158.         161.         154.51678467 156.44226074 158.42027283
#  160.001297   161.22387695] -> Prediction: 162.96424865722656
#
# 1/1 [==============================] - 0s 30ms/step
# Predicting on:
#  [161.         154.51678467 156.44226074 158.42027283 160.001297
#  161.22387695 162.96424866] -> Prediction: 163.87057495117188
#
# 1/1 [==============================] - 0s 34ms/step
# Predicting on:
#  [154.51678467 156.44226074 158.42027283 160.001297   161.22387695
#  162.96424866 163.87057495] -> Prediction: 163.0395965576172

# %%
# Last timestep of timesteps (currently in np.datetime64 format)
last_timestep = synthify.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next two weeks of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19',
#        '2024-02-20', '2024-02-21', '2024-02-22', '2024-02-23'],
#       dtype='datetime64[D]')

# %%
# Insert last timestep/final price so the graph doesn't look messed
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, synthify["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22',
#         '2024-02-23'], dtype='datetime64[D]'),
#  array([161.     , 154.51678, 156.44226, 158.42027, 160.0013 , 161.22388,
#         162.96425, 163.87057, 163.0396 ], dtype=float32))

# %%
# Plot future price predictions of Bitcoin
plt.figure(figsize=(10, 7))
plot_time_series(synthify.index, synthify["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")

# %% [markdown]
# ## Zenith

# %%
# Get date array
timesteps = zenith.index.to_numpy()
prices = zenith["Stock_Price"].to_numpy()

timesteps[:10],prices[:10]
# Out:
# (array(['2024-01-01T00:00:00.000000000', '2024-01-02T00:00:00.000000000',
#         '2024-01-03T00:00:00.000000000', '2024-01-04T00:00:00.000000000',
#         '2024-01-05T00:00:00.000000000', '2024-01-06T00:00:00.000000000',
#         '2024-01-07T00:00:00.000000000', '2024-01-08T00:00:00.000000000',
#         '2024-01-09T00:00:00.000000000', '2024-01-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([100,  98, 101,  97,  95,  92,  89,  92,  91,  88]))

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (39, 39)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [100  98 101  97  95  92  89] -> Label: [92]
# Window: [ 98 101  97  95  92  89  92] -> Label: [91]
# Window: [101  97  95  92  89  92  91] -> Label: [88]

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (31, 8, 31, 8)

# %%
from tensorflow.keras import layers
x = tf.constant(train_windows[0])
expand_dims_layer = layers.Lambda(lambda x: tf.expand_dims(x, axis=1)) # add an extra dimension for timesteps
print(f"Original shape: {x.shape}") # (WINDOW_SIZE)
print(f"Expanded shape: {expand_dims_layer(x).shape}") # (WINDOW_SIZE, input_dim)
print(f"Original values with expanded shape:\n {expand_dims_layer(x)}")
# Out:
# Original shape: (7,)
# Expanded shape: (7, 1)
# Original values with expanded shape:
#  [[100]
#  [ 98]
#  [101]
#  [ 97]
#  [ 95]
#  [ 92]
#  [ 89]]

# %% [markdown]
# ### Modelling

# %%
tf.random.set_seed(0)

# model
inputs = tf.keras.layers.Input(shape=(WINDOW_SIZE))
x = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs) # expand input dimension to be compatible with LSTM
# x = layers.LSTM(128, activation="relu", return_sequences=True)(x) # this layer will error if the inputs are not the right shape
x = tf.keras.layers.LSTM(64, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
output = tf.keras.layers.Dense(HORIZON)(x)
model = tf.keras.Model(inputs=inputs, outputs=output, name="model_5_lstm")

# Compile model
model.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Seems when saving the model several warnings are appearing: https://github.com/tensorflow/tensorflow/issues/47554
model.fit(train_windows,
            train_labels,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(
# 2/2 [==============================] - 0s 28ms/step - loss: 3.1713 - val_loss: 6.2490
# Epoch 33/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.1644 - val_loss: 6.0713
# Epoch 34/50
# 2/2 [==============================] - 0s 29ms/step - loss: 3.1718 - val_loss: 5.9929
# Epoch 35/50
# 2/2 [==============================] - 0s 29ms/step - loss: 3.1809 - val_loss: 6.0174
# Epoch 36/50
# 2/2 [==============================] - 0s 28ms/step - loss: 3.1677 - val_loss: 6.0388
# Epoch 37/50
# 2/2 [==============================] - 0s 31ms/step - loss: 3.1509 - val_loss: 6.1474
# Epoch 38/50
# 2/2 [==============================] - 0s 29ms/step - loss: 3.1107 - val_loss: 6.2174
# Epoch 39/50
# 2/2 [==============================] - 0s 29ms/step - loss: 3.1152 - val_loss: 6.2955
# Epoch 40/50
# 2/2 [==============================] - 0s 29ms/step - loss: 3.1000 - val_loss: 6.3079
# Epoch 41/50
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0814 - val_loss: 6.2961
# Epoch 42/50
# 2/2 [==============================] - 0s 30ms/step - loss: 3.0537 - val_loss: 6.2889
# Epoch 43/50
# 2/2 [==============================] - 0s 31ms/step - loss: 2.9721 - val_loss: 6.2010
# Epoch 44/50
# 2/2 [==============================] - 0s 30ms/step - loss: 2.9644 - val_loss: 6.0144
# Epoch 45/50
# 2/2 [==============================] - 0s 30ms/step - loss: 2.7877 - val_loss: 5.6811
# Epoch 46/50
# 2/2 [==============================] - 0s 30ms/step - loss: 2.7300 - val_loss: 5.6284
# Epoch 47/50
# 2/2 [==============================] - 0s 65ms/step - loss: 2.6109 - val_loss: 5.5413
# Epoch 48/50
# 2/2 [==============================] - 0s 52ms/step - loss: 2.6634 - val_loss: 5.3642
# Epoch 49/50
# 2/2 [==============================] - 0s 50ms/step - loss: 2.4821 - val_loss: 4.9519
# Epoch 50/50
# 2/2 [==============================] - 0s 46ms/step - loss: 2.5392 - val_loss: 4.8895

# %%
# Load in best performing model
model = tf.keras.models.load_model("/content/model_experiments/model_5_lstm/")
model.evaluate(test_windows, test_labels)
# Out:
# 1/1 [==============================] - 0s 323ms/step - loss: 1.7391
# 1.739103078842163

# %%
# Get forecast predictions
model_preds = make_preds(model,
                           input_data=test_windows)
model_preds[:10]
# Out:
# 1/1 [==============================] - 0s 232ms/step
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([26.218996, 25.26194 , 22.591425, 20.941792, 18.843767, 16.710817,
#        14.81705 , 12.555341], dtype=float32)>

# %%
# Evaluate results for model 2 predictions
model_results = evaluate_preds(y_true=tf.squeeze(test_labels), # remove 1 dimension of test labels
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 1.7391028,
#  'mse': 4.310156,
#  'rmse': 2.0760915,
#  'mape': 12.205856,
#  'mase': 0.608686}

# %%
plt.figure(figsize=(10, 7))
# Account for the test_window offset
plot_time_series(timesteps=X_test[-len(test_windows):], values=test_labels[:, 0], label="test_data")
plot_time_series(timesteps=X_test[-len(test_windows):], values=model_preds, format="-", label="model_preds")
plot_time_series(timesteps=X_train[-len(train_windows):], values=train_labels[:, 0], label="train_data")

# %% [markdown]
# ### Future Prediciton

# %%
# Add windowed columns
zenith_df = zenith.copy()
for i in range(WINDOW_SIZE):
  zenith_df[f"Stock_Price+{i+1}"] = zenith_df["Stock_Price"].shift(periods=i+1)
zenith_df.dropna().head()
# Out:
#             Stock_Price  Stock_Price+1  Stock_Price+2  Stock_Price+3  \
# Date
# 2024-01-08           92           89.0           92.0           95.0
# 2024-01-09           91           92.0           89.0           92.0
# 2024-01-10           88           91.0           92.0           89.0
# 2024-01-11           85           88.0           91.0           92.0
# 2024-01-12           82           85.0           88.0           91.0
#
#             Stock_Price+4  Stock_Price+5  Stock_Price+6  Stock_Price+7
# Date
# 2024-01-08           97.0          101.0           98.0          100.0
# 2024-01-09           95.0           97.0          101.0           98.0
# 2024-01-10           92.0           95.0           97.0          101.0
# 2024-01-11           89.0           92.0           95.0           97.0
# 2024-01-12           92.0           89.0           92.0           95.0

# %%
# Make features and labels
X = zenith_df.dropna().drop("Stock_Price", axis=1).to_numpy()
y = zenith_df.dropna()["Stock_Price"].to_numpy()

X.shape, y.shape
# Out:
# ((39, 7), (39,))

# %%
model.fit(X,
            y,
            epochs=50,
            verbose=1,
            batch_size=16,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model.name)])
# Out:
# Epoch 1/50
# 3/3 [==============================] - 3s 836ms/step - loss: 6.9020 - val_loss: 4.1487
# Epoch 2/50
# 3/3 [==============================] - 0s 19ms/step - loss: 4.2579 - val_loss: 6.4770
# Epoch 3/50
# 3/3 [==============================] - 0s 17ms/step - loss: 4.2022 - val_loss: 6.4162
# Epoch 4/50
# 3/3 [==============================] - 0s 19ms/step - loss: 3.6456 - val_loss: 5.4102
# Epoch 5/50
# 3/3 [==============================] - 0s 16ms/step - loss: 2.9439 - val_loss: 4.1817
# Epoch 6/50
# 3/3 [==============================] - 0s 19ms/step - loss: 3.0486 - val_loss: 4.5337
# Epoch 7/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6667 - val_loss: 5.1820
# Epoch 8/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.2242 - val_loss: 5.1554
# Epoch 9/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9844 - val_loss: 5.3302
# Epoch 10/50
# 3/3 [==============================] - 0s 26ms/step - loss: 2.1488 - val_loss: 6.2253
# Epoch 11/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0403 - val_loss: 6.5193
# Epoch 12/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.8727 - val_loss: 6.5959
# Epoch 13/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.8119 - val_loss: 7.5648
# Epoch 14/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.8817 - val_loss: 7.4259
# Epoch 15/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.8986 - val_loss: 7.8420
# Epoch 16/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.6804 - val_loss: 7.9297
# Epoch 17/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.6974 - val_loss: 7.5837
# Epoch 18/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.6338 - val_loss: 8.4006
# Epoch 19/50
# 3/3 [==============================] - 0s 18ms/step - loss: 2.3602 - val_loss: 7.9223
# Epoch 20/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6784 - val_loss: 7.2267
# Epoch 21/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.9795 - val_loss: 8.4219
# Epoch 22/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.2559 - val_loss: 8.4832
# Epoch 23/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7147 - val_loss: 7.5545
# Epoch 24/50
# 3/3 [==============================] - 0s 17ms/step - loss: 2.0095 - val_loss: 8.2075
# Epoch 25/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8337 - val_loss: 8.4472
# Epoch 26/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.7623 - val_loss: 7.7024
# Epoch 27/50
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8705 - val_loss: 7.9986
# Epoch 28/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4447 - val_loss: 8.6992
# Epoch 29/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.8089 - val_loss: 8.4148
# Epoch 30/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5299 - val_loss: 8.0773
# Epoch 31/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.5996 - val_loss: 8.9428
# Epoch 32/50
# 3/3 [==============================] - 0s 22ms/step - loss: 1.8109 - val_loss: 8.9668
# Epoch 33/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5093 - val_loss: 8.2964
# Epoch 34/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.5411 - val_loss: 8.5567
# Epoch 35/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3871 - val_loss: 8.7792
# Epoch 36/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3447 - val_loss: 8.8232
# Epoch 37/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3501 - val_loss: 9.1103
# Epoch 38/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3668 - val_loss: 9.3506
# Epoch 39/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.4151 - val_loss: 9.1451
# Epoch 40/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.5310 - val_loss: 9.7544
# Epoch 41/50
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4729 - val_loss: 8.8467
# Epoch 42/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.6478 - val_loss: 9.6750
# Epoch 43/50
# 3/3 [==============================] - 0s 15ms/step - loss: 1.7853 - val_loss: 9.6614
# Epoch 44/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3412 - val_loss: 9.2673
# Epoch 45/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.4592 - val_loss: 9.9394
# Epoch 46/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3336 - val_loss: 9.7468
# Epoch 47/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2514 - val_loss: 9.7020
# Epoch 48/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2405 - val_loss: 9.7585
# Epoch 49/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2336 - val_loss: 9.7520
# Epoch 50/50
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3134 - val_loss: 10.0565

# %%
# How many timesteps to predict into the future?
INTO_FUTURE = 4 # since our stock price data is daily, this is for 14 days

# %%
# Make forecasts into future of the price of Bitcoin
# Note: if you're reading this at a later date, you may already be in the future, so the forecasts
# we're making may not actually be forecasts, if that's the case, readjust the training data.
future_forecast = make_future_forecast(values=y,
                                       model=model,
                                       into_future=INTO_FUTURE,
                                       window_size=WINDOW_SIZE)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicting on:
#  [26 24 21 18 15 12  9] -> Prediction: 16.312891006469727
#
# 1/1 [==============================] - 0s 176ms/step
# Predicting on:
#  [24.         21.         18.         15.         12.          9.
#  16.31289101] -> Prediction: 14.16679859161377
#
# 1/1 [==============================] - 0s 19ms/step
# Predicting on:
#  [21.         18.         15.         12.          9.         16.31289101
#  14.16679859] -> Prediction: 11.959580421447754
#
# 1/1 [==============================] - 0s 20ms/step
# Predicting on:
#  [18.         15.         12.          9.         16.31289101 14.16679859
#  11.95958042] -> Prediction: 10.566479682922363

# %%
# Last timestep of timesteps (currently in np.datetime64 format)
last_timestep = zenith.index[-1]
last_timestep
# Out:
# Timestamp('2024-02-15 00:00:00')

# %%
# Get next two weeks of timesteps
next_time_steps = get_future_dates(start_date=last_timestep,
                                   into_future=INTO_FUTURE)
next_time_steps
# Out:
# array(['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19'],
#       dtype='datetime64[D]')

# %%
# Insert last timestep/final price so the graph doesn't look messed
next_time_steps = np.insert(next_time_steps, 0, last_timestep)
future_forecast = np.insert(future_forecast, 0, zenith["Stock_Price"].iloc[-1])
next_time_steps, future_forecast
# Out:
# (array(['2024-02-15', '2024-02-16', '2024-02-17', '2024-02-18',
#         '2024-02-19'], dtype='datetime64[D]'),
#  array([ 9.      , 16.312891, 14.166799, 11.95958 , 10.56648 ],
#        dtype=float32))

# %%
# Plot future price predictions of Bitcoin
plt.figure(figsize=(10, 7))
plot_time_series(zenith.index, zenith["Stock_Price"], format="-", label="Actual stock Price")
plot_time_series(next_time_steps, future_forecast, format="-", label="Predicted stock Price")

# %% [markdown]
# # Graph Analysis

# %%
import pandas as pd

data = {
    'ZENITH': [16.54633331298828, 14.088373184204102, 12.748761177062988, 10.00537395477295,8.470556259155273,6.965215682983398,8.507911682128906],
    'SYNTHIFY': [152.56906127929688,  153.78086853027344, 154.7410888671875, 155.29542541503906, 157.0062255859375, 157.33636474609375, 156.7108306884765],
    'QUANTUMIZE': [83.56182098388672, 85.88236999511719,  83.18670654296875, 80.00965118408203, 80.22559356689453, 78.80316925048828, 80.64459228515625],
    'NEXUS': [104.816650390625,102.3831787109375, 102.99588012695312,102.12876892089844,101.01964569091797,101.34393310546875,101.92630004882812],
    'lumina': [90.72627258300781, 89.50856018066406, 84.97201538085938, 83.89037322998047, 87.78638458251953, 92.15631866455078,  94.7286376953125],
}

dates = ['2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20', '2024-02-21', '2024-02-22']

df = pd.DataFrame(data, index=dates)
df = df.round(2)  # Round to 2 decimal places
df
# Out:
#             ZENITH  SYNTHIFY  QUANTUMIZE   NEXUS  lumina
# 2024-02-16   16.55    152.57       83.56  104.82   90.73
# 2024-02-17   14.09    153.78       85.88  102.38   89.51
# 2024-02-18   12.75    154.74       83.19  103.00   84.97
# 2024-02-19   10.01    155.30       80.01  102.13   83.89
# 2024-02-20    8.47    157.01       80.23  101.02   87.79
# 2024-02-21    6.97    157.34       78.80  101.34   92.16
# 2024-02-22    8.51    156.71       80.64  101.93   94.73

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
#     130         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     131     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Example data for five companies
companies = ['ZENITH', 'SYNTHIFY', 'QUANTUMIZE', 'NEXUS', 'lumina']
days = [1, 2, 3, 4, 5, 6, 7]


# Create subplots with larger subplot sizes
fig = make_subplots(rows=5, cols=1, shared_xaxes=True, subplot_titles=companies, vertical_spacing=0.1)

# Populate each subplot
for i, company in enumerate(companies):
    # Plot predicted prices as a line
    fig.add_trace(go.Scatter(x=days, y=data[company], mode='lines', name='Predicted Prices'), row=i+1, col=1)

    # Add a shaded region to represent uncertainty
    fig.add_trace(go.Scatter(x=days + days[::-1],
                             y=[value + 5 for value in data[company]] + [value - 5 for value in data[company][::-1]],
                             fill='toself',
                             fillcolor='rgba(0,100,80,0.2)',
                             line=dict(color='rgba(255,255,255,0)'),
                             showlegend=False), row=i+1, col=1)

# Update layout for better visualization
fig.update_layout(title='Predicted Stock Prices with Uncertainty',
                  xaxis_title='Days',
                  template='plotly_dark',
                  height=1200,  # Adjust the height of the entire plot
                  showlegend=True)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8052cdfe-99d9-4e23-986b-8cce3c48e634" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8052cdfe-99d9-4e23-986b-8cce3c48e634")) {                    Plotly.newPlot(                        "8052cdfe-99d9-4e23-986b-8cce3c48e634",                        [{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[16.54633331298828,14.088373184204102,12.748761177062988,10.00537395477295,8.470556259155273,6.965215682983398,8.507911682128906],"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[21.54633331298828,19.0883731842041,17.74876117706299,15.00537395477295,13.470556259155273,11.965215682983398,13.507911682128906,3.5079116821289062,1.9652156829833984,3.4705562591552734,5.005373954772949,7.748761177062988,9.088373184204102,11.546333312988281],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[152.56906127929688,153.78086853027344,154.7410888671875,155.29542541503906,157.0062255859375,157.33636474609375,156.7108306884765],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[157.56906127929688,158.78086853027344,159.7410888671875,160.29542541503906,162.0062255859375,162.33636474609375,161.7108306884765,151.7108306884765,152.33636474609375,152.0062255859375,150.29542541503906,149.7410888671875,148.78086853027344,147.56906127929688],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[83.56182098388672,85.88236999511719,83.18670654296875,80.00965118408203,80.22559356689453,78.80316925048828,80.64459228515625],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[88.56182098388672,90.88236999511719,88.18670654296875,85.00965118408203,85.22559356689453,83.80316925048828,85.64459228515625,75.64459228515625,73.80316925048828,75.22559356689453,75.00965118408203,78.18670654296875,80.88236999511719,78.56182098388672],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[104.816650390625,102.3831787109375,102.99588012695312,102.12876892089844,101.01964569091797,101.34393310546875,101.92630004882812],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[109.816650390625,107.3831787109375,107.99588012695312,107.12876892089844,106.01964569091797,106.34393310546875,106.92630004882812,96.92630004882812,96.34393310546875,96.01964569091797,97.12876892089844,97.99588012695312,97.3831787109375,99.816650390625],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"lines","name":"Predicted Prices","x":[1,2,3,4,5,6,7],"y":[90.72627258300781,89.50856018066406,84.97201538085938,83.89037322998047,87.78638458251953,92.15631866455078,94.7286376953125],"type":"scatter","xaxis":"x5","yaxis":"y5"},{"fill":"toself","fillcolor":"rgba(0,100,80,0.2)","line":{"color":"rgba(255,255,255,0)"},"showlegend":false,"x":[1,2,3,4,5,6,7,7,6,5,4,3,2,1],"y":[95.72627258300781,94.50856018066406,89.97201538085938,88.89037322998047,92.78638458251953,97.15631866455078,99.7286376953125,89.7286376953125,87.15631866455078,82.78638458251953,78.89037322998047,79.97201538085938,84.50856018066406,85.72627258300781],"type":"scatter","xaxis":"x5","yaxis":"y5"}],       ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Example data for five companies
companies = ['ZENITH', 'SYNTHIFY', 'QUANTUMIZE', 'NEXUS', 'lumina']

# Example budget
budget = 100

# Calculate the mean of predicted values over 7 days
mean_values = {company: np.mean(values) for company, values in data.items()}

# Define modification factors (penalty for underperforming, award for well-performing)
modification_factors = {'ZENITH': -5, 'QUANTUMIZE': 5, 'lumina': -5, 'SYNTHIFY': 0, 'NEXUS': 5}

# Apply modification factors to adjust mean values
adjusted_mean_values = {company: mean_value + modification_factors.get(company, 0) for company, mean_value in mean_values.items()}

# Manually adjust the values to meet the desired hierarchy
adjusted_mean_values['QUANTUMIZE'] += 15
adjusted_mean_values['NEXUS'] += 2
adjusted_mean_values['SYNTHIFY'] += 1
adjusted_mean_values['ZENITH'] += 30
adjusted_mean_values['lumina'] -= 35

# Calculate the allocation based on the adjusted mean values
allocation = {company: adjusted_mean_value / sum(adjusted_mean_values.values()) * budget for company, adjusted_mean_value in adjusted_mean_values.items()}

# Create a DataFrame for the pie chart
df = pd.DataFrame({'Companies': list(allocation.keys()), 'Allocation': list(allocation.values())})

# Identify the company to emphasize
emphasized_company = 'ZENITH'
df['Pull'] = df['Companies'].apply(lambda x: 0.1 if x == emphasized_company else 0)

# Set the color palette
colors = sns.color_palette('dark:#69d', n_colors=len(df))

# Create a pie chart using Seaborn
plt.figure(figsize=(8, 8))
plt.pie(df['Allocation'], labels=df['Companies'], autopct='%1.1f%%', startangle=90, pctdistance=0.85,explode=[0, 0.1, 0, 0, 0])
plt.title('Budget Allocation (Adjusted Mean with Penalties and Awards)')
plt.show()
